# %%
import pandas as pd

# %%
df=pd.DataFrame([[1,4,5],[4,5,6],[34,53,65]],columns=['q','w','e'],index=['a','b','c'])

# %%
df=pd.read_csv('/content/student-mat.csv')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
display(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.sample(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 93      GP   F   16       U     GT3       T     4     2  teacher  services
# 184     GP   F   16       U     GT3       T     3     2    other     other
# 312     GP   M   19       U     GT3       T     1     2    other  services
# 234     GP   M   16       U     LE3       T     1     1    other     other
# 302     GP   F   17       U     GT3       T     4     2    other     other
# 142     GP   F   15       U     GT3       T     4     4  teacher  services
# 105     GP   F   15       U     GT3       A     3     3    other    health
# 351     MS   M   17       U     GT3       T     3     3   health     other
# 273     GP   M   17       R     GT3       T     1     2  at_home   at_home
# 17      GP   F   16       U     GT3       T     3     3    other     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 93   ...      5        3      3     1     1      1        0  11  10  10
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
#loc(work with row and column) and iloc(works with index number)
df.loc[0:4,["school","age","address"]]
# Out:
#   school  age address
# 0     GP   18       U
# 1     GP   17       U
# 2     GP   15       U
# 3     GP   15       U
# 4     GP   16       U

# %%
#we can replace numeric index with any column

df.index=df.Fjob

# %%
df.loc["at_home","school"]
# Out:
# Fjob
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    GP
# at_home    MS
# at_home    MS
# at_home    MS
# at_home    MS
# Name: school, dtype: object

# %%
 #we can modify value at specific place
 df.loc[2,'age']=17

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   17       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#sorting with the help of column
df.sort_values("school",ascending=False, inplace=True)
print(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 373     MS   F   17       R     GT3       T     1     2     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 392     MS   M   21       R     GT3       T     1     1     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 312     GP   M   19       U     GT3       T     1     2     other  services
# 314     GP   F   19       U     GT3       T     1     1   at_home    health
# 334     GP   F   18       R     GT3       T     2     2   at_home     other
# 335     GP   F   17       U     GT3       T     3     4  services     other
# 197     GP   M   16       R     LE3       T     3     3   teacher     other
#
# ...

# %%
#Filtering Data
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.loc[df["age"]>15,["school","sex","age"]]  #getting students with age GT 15
#or
df[df["age"]>15]
#OR
df[(df["age"]>15) & (df["health"]>3)] #multiconditions
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 17      GP   F   16       U     GT3       T     3     3     other     other
# 18      GP   M   17       U     GT3       T     3     2  services  services
# 19      GP   M   16       U     LE3       T     4     3    health     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
#can use str method for applying conditions
df[df['Mjob'].str.contains("at_home")]
df[df['Mjob'].str.contains("at_home|health")]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 12      GP   M   15       U     LE3       T     4     4   health  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 368     MS   F   18       U     GT3       T     2     3  at_home  services
# 371     MS   M   18       R     LE3       T     1     2  at_home  services
# 376     MS   F   20       U     GT3       T     4     2   health     other
# 379     MS   F   17       R     GT3       T     3     1  at_home     other
# 385     MS   F   18       R     GT3       T     2     2  at_home     other
#
# ...

# %%
#3Getting confortable with QUERY function

df.query('age > 15')

df.query('famrel==4')

df.query('health>2' and 'Mjob=="at_home"')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 39      GP   F   15       R     GT3       T     2     2  at_home     other
# 79      GP   F   16       U     GT3       T     3     4  at_home     other
# 86      GP   F   16       U     LE3       T     2     2  at_home     other
# 95      GP   F   15       R     GT3       T     1     1  at_home     other
# 112     GP   F   16       U     GT3       T     2     2  at_home     other
# 120     GP   F   15       U     GT3       T     1     2  at_home  services
# 127     GP   F   19       U     GT3       T     0     1  at_home     other
# 131     GP   F   15       U     GT3       T     1     1  at_home     other
# ...

# %% [markdown]
# add and remove columns

# %%
#add specific value
df.loc[1,'age']=32
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   32       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
#adding new column

df['new_col']=5

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   32       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
import numpy as np
df['new_col']=np.where(df['health']==3,400,231)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   32       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.sample()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 224     GP   F   16       U     GT3       T     4     4  teacher  services
#
#      ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 new_col
# 224  ...        3     2     1     1       5        0  13  13  14     231
#
# [1 rows x 34 columns]

# %%
df=df.drop('new_col',axis=1)

# %%
#adding new column by multipying
df['multiply']=df['health']*df['new_col']

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   32       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
#can rename the columns

df.rename(columns={'multiply':'Rough_val'})
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   32       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
new_df=pd.read_csv('/content/base_etablissement_par_tranche_effectif.csv')

# %%
new_df
# Out:
#       CODGEO                   LIBGEO  REG  DEP  E14TST  E14TS0ND  E14TS1  \
# 0      01001  L'Abergement-Clémenciat   82   01      25        22       1
# 1      01002    L'Abergement-de-Varey   82   01      10         9       1
# 2      01004        Ambérieu-en-Bugey   82   01     996       577     272
# 3      01005      Ambérieux-en-Dombes   82   01      99        73      20
# 4      01006                  Ambléon   82   01       4         4       0
# ...      ...                      ...  ...  ...     ...       ...     ...
# 36676  97613            M'Tsangamouji    6  976     169       169       0
# 36677  97614                 Ouangani    6  976     230       230       0
# 36678  97615                 Pamandzi    6  976     569       569       0
# 36679  97616                     Sada    6  976     345       345       0
# 36680  97617                 Tsingoni    6  976     348       348       0
#
#        E14TS6  E14TS10  E14TS20  E14TS50  E14TS100  E14TS200  E14TS500
# ...
